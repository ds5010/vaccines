# %%
import pandas as pd
import gzip
# df = pd.read_csv('/data/COVID-19_Vaccinations_in_the_United_States_County.csv.gz',
#                  index_col='Date')
# print(df)
# print(type(df.index_col))
# print(df.to_datetime)
# start_date=''
# end_date=''
df = pd.read_csv('data/COVID-19_Vaccinations_in_the_United_States_County.csv.gz', compression='gzip')
print(type(df.iloc[1]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df
# Out:
#                Date   FIPS  MMWR_week            Recip_County Recip_State  \
# 0        02/13/2022  01081          7              Lee County          AL
# 1        02/13/2022  18033          7           DeKalb County          IN
# 2        02/13/2022  27033          7       Cottonwood County          MN
# 3        02/13/2022  24033          7  Prince George's County          MD
# 4        02/13/2022  27007          7         Beltrami County          MN
# ...             ...    ...        ...                     ...         ...
# 1404596  12/13/2020  26097         51         Mackinac County          MI
# 1404597  12/13/2020  51735         51           Poquoson city          VA
# 1404598  12/13/2020  42011         51            Berks County          PA
# 1404599  12/13/2020  31059         51         Fillmore County          NE
# 1404600  12/13/2020  31079         51             Hall County          NE
#
#          Completeness_pct  Administered_Dose1_Recip  \
# ...

# %%
print(type(df.Date))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#df.dtypes
df['Date']=pd.to_datetime(df.Date)
df.Date
# Out:
# 0         2022-02-13
# 1         2022-02-13
# 2         2022-02-13
# 3         2022-02-13
# 4         2022-02-13
#              ...
# 1404596   2020-12-13
# 1404597   2020-12-13
# 1404598   2020-12-13
# 1404599   2020-12-13
# 1404600   2020-12-13
# Name: Date, Length: 1404601, dtype: datetime64[ns]

# %%
#df.dtypes
#df.Date.dt.date
start_date=pd.to_datetime('5/1/2021')
end_date=pd.to_datetime('11/30/2021')
print(start_date)
print(end_date)
# df=df.loc[df.Date>=start_date][df.Date<=end_date]
df=df.loc[df.Date:end_date]
print(df)
# Out:
# 2021-05-01 00:00:00
# 2021-11-30 00:00:00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-00ee18736fb2> in <module>
#       6 print(end_date)
#       7 # df=df.loc[df.Date>=start_date][df.Date<=end_date]
# ----> 8 df=df.loc[df.Date:end_date]
#       9 print(df)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1100         if isinstance(key, slice):
#    1101             self._validate_key(key, axis)
# -> 1102             return self._get_slice_axis(key, axis=axis)
# ...

# %%
import shutil
with open(df.to_csv(),'rt') as f_input:
    with gzip.open('COVID-19_Vaccinations_in_the_United_States_County_start_date_to_end_date.csv.gz', 'wb') as f_output:
        shutil.copyfileobj(f_input, f_output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-5b789192e04c> in <module>
#       2 f_input=df.to_csv()
#       3 with gzip.open('COVID-19_Vaccinations_in_the_United_States_County_start_date_to_end_date.csv.gz', 'wb') as f_output:
# ----> 4     shutil.copyfileobj(f_input, f_output)
#
# ~/opt/anaconda3/lib/python3.8/shutil.py in copyfileobj(fsrc, fdst, length)
#     200     if not length:
#     201         length = COPY_BUFSIZE
# --> 202     fsrc_read = fsrc.read
#     203     fdst_write = fdst.write
#     204     while True:
#
# AttributeError: 'str' object has no attribute 'read'

# %%
import pandas as pd
import gzip
df = pd.read_csv('May_1st_to_November_30th.csv.gz',compression='gzip')
df
# Out:
#               Date   FIPS  MMWR_week      Recip_County Recip_State  \
# 0       2021-11-30  19093         48        Ida County          IA
# 1       2021-11-30  06015         48  Del Norte County          CA
# 2       2021-11-30  20207         48    Woodson County          KS
# 3       2021-11-30  08109         48   Saguache County          CO
# 4       2021-11-30  29161         48     Phelps County          MO
# ...            ...    ...        ...               ...         ...
# 702383  2021-05-01  37135         17     Orange County          NC
# 702384  2021-05-01  20119         17      Meade County          KS
# 702385  2021-05-01  51027         17   Buchanan County          VA
# 702386  2021-05-01  06061         17     Placer County          CA
# 702387  2021-05-01  48185         17     Grimes County          TX
#
#         Completeness_pct  Administered_Dose1_Recip  \
# 0                   97.4                    3408.0
# 1                   97.4                   12619.0
# ...
